# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
# Our first graph of the cleaned data set will be 
# simply graphing latitude on x axis 
# and longitude on y axis using a scatter plot

df = pd.read_csv('data_set/M_Landings_cleaned.csv')

# lat_x = ['23', '45', '34', '92', '13', '09', '66']
# long_y = ['12', '56', '90', '34' , '56', '87', '06']

# lat_x = [df['']]
# plt.plot(lat_x, long_y)
# df.head()


# while this graph is accurate it does not provide much 
# value as far as insights
df.plot(kind='scatter', x='reclat', y='reclong')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('Meteor Landings')
# plt.legend('Meteor sitings')
plt.show()

# %%
# the same plot using matplot lib libraries instead of pandas dataframe
plt.scatter(df['reclat'], df['reclong'])
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('Meteor Landings')
plt.show()

# %%
# this time we will graph the year and the mass on the same plot

# plt.scatter(df['GeoLocation'], df['reclat'], color='g')
# plt.scatter(df['GeoLocation'], df['reclong'], color='r')
# plt.xlabel('GeoLocation')
# plt.ylabel('mass/year')
# plt.title('mass vs year')
# plt.show()

# %%
df.head()
# Out:
#     id  year  mass (g)  reclat  reclong     GeoLocation
# 0    1  1880      21.0   50.78     6.08     50.78, 6.08
# 1    2  1951     720.0   56.18    10.23    56.18, 10.23
# 2    6  1952  107000.0   54.22  -113.00   54.22, -113.0
# 3   10  1976    1914.0   16.88   -99.90    16.88, -99.9
# 4  370  1902     780.0  -33.17   -64.95  -33.17, -64.95

# %%
# lets try this again with multiple plots
# The first plot will be (x,y) (GeoLocation, Mass)
# The second plot will be (x,y) (GeoLocation, Year)

df.plot(kind='line', x = 'GeoLocation', y = 'mass (g)')
# df.plot(kind='bar', x = 'GeoLocation', y = 'year')
plt.title('GeolLocations vs Mass (g)')
plt.show()

# %%
df.plot(kind='line', x ='GeoLocation', y='year')
plt.title('Geolocation vs Year')
plt.show()

# %%
# while these plots are acurate they do not show much value without context
# need to show these points on a map of the world 
# this can be done using the basemap library from matplotlib
